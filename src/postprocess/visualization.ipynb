# %% [markdown]
# ## This script is used to visualize the results from PEST++IES

# %%
# import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
outpath = '../../output/work_run_0410/'
fig_path = '../../output/figs/'
for n in range(10, 15):
    par_temp = pd.read_csv(f'{outpath}126001A.14.par.csv', index_col = 'real_name')
    try:
        pars = pd.concat([pars, par_temp])
    except NameError:
        pars = pd.read_csv(f'{outpath}126001A.14.par.csv', index_col = 'real_name')
pars.shape
# Out:
# (200, 14)

# %%
# select the parameter columns to plot
joint_columns = pars.columns[4:]

# %%
fig = plt.figure(figsize=(10, 10))
sns.set(font_scale=1.2)
ax = sns.pairplot(pars[joint_columns],kind='scatter',diag_kind='hist')
plt.savefig(f'{fig_path}pairplot_5-10.png', format='png', dpi=300)
